# %%
import random
# Import the NumPy module.
import numpy as np
import pandas as pd

# Import the time library and the datetime module from the datetime library 
import time
import timeit
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
import pprint

# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
cities
# Out:
# ['ushuaia',
#  'butaritari',
#  'porto novo',
#  'bilma',
#  'nanortalik',
#  'necochea',
#  'illoqqortoormiut',
#  'puerto ayora',
#  'punta arenas',
#  'hilo',
#  'tuktoyaktuk',
#  'tasiilaq',
#  'airai',
#  'kenai',
#  'severo-kurilsk',
#  'rebrikha',
#  'cape town',
#  'kodiak',
#  'fort nelson',
#  'portland',
#  'rikitea',
#  'east london',
#  'avarua',
#  'bubaque',
#  'aykhal',
#  'teguldet',
#  'omsukchan',
#  'cabo san lucas',
#  'ostrovnoy',
#  'clemson',
#  'shahganj',
#  'wanning',
#  'revyakino',
#  'mataura',
#  'barrow',
#  'vaini',
#  'clyde river',
#  'riyadh',
#  'ambon',
#  'thompson',
#  'corinto',
#  'tirumala',
#  'seljord',
#  'marawi',
#  'hermanus',
#  'provideniya',
#  'castro',
#  'umm kaddadah',
#  'kapaa',
#  'ponta delgada',
#  'haines junction',
#  'solnechnyy',
#  'taolanaro',
#  'ayodhya',
#  'saint-philippe',
#  'manta',
#  'pisco',
#  'okha',
#  'dikson',
#  'port hawkesbury',
#  'evinayong',
#  'meulaboh',
#  'tete',
#  'kaitangata',
#  'plettenberg bay',
#  'codrington',
#  'dunedin',
#  'leningradskiy',
#  'jamestown',
#  'bozeman',
#  'atuona',
#  'port lincoln',
#  'carnarvon',
#  'iquique',
#  'mar del plata',
#  'amderma',
#  'bluff',
#  'hasaki',
#  'kollam',
#  'biak',
#  'cherskiy',
#  'port alfred',
#  'uige',
#  'sataua',
#  'bethel',
#  'le creusot',
#  'kushmurun',
#  'billings',
#  'atikokan',
#  'hokitika',
#  'ancud',
#  'aklavik',
#  'bo',
#  'qaanaaq',
#  'gornozavodsk',
#  'busselton',
#  'karmana',
#  'chernyanka',
#  'visnes',
#  'tura',
#  'chokurdakh',
#  'bitkine',
#  'sentyabrskiy',
#  'balakliya',
#  'cody',
#  'albany',
#  'sena madureira',
#  'garden city',
#  'grand river south east',
#  'praia',
#  'petatlan',
#  'faanui',
#  'archidona',
#  'olga',
#  'arraial do cabo',
#  'sept-iles',
#  'marsaxlokk',
#  'eyl',
#  'bonavista',
#  'tuy hoa',
#  'buala',
#  'barentsburg',
#  'mandera',
#  'yellowknife',
#  'chuy',
#  'dhidhdhoo',
#  'waingapu',
#  'kruisfontein',
#  'webuye',
#  'rio gallegos',
#  'kalmeshwar',
#  'lucea',
#  'pevek',
#  'prainha',
#  'longyearbyen',
#  'nyurba',
#  'ponta do sol',
#  'nikolskoye',
#  'sorocaba',
#  'bembereke',
#  'nizhneyansk',
#  'saskylakh',
#  'padang',
#  'pacific grove',
#  'anloga',
#  'attawapiskat',
#  'am timan',
#  'ilulissat',
#  'koumac',
#  'coahuayana',
#  'samarai',
#  'columbus',
#  'hobart',
#  'bengkulu',
#  'port-gentil',
#  'san cristobal',
#  'vanimo',
#  'chernushka',
#  'tazovskiy',
#  'alyangula',
#  'lavrentiya',
#  'oskemen',
#  'salalah',
#  'taonan',
#  'lodwar',
#  'zaozerne',
#  'mahebourg',
#  'nome',
#  'burica',
#  'tsihombe',
#  'izacic',
#  'samalaeulu',
#  'namatanai',
#  'upernavik',
#  'natchez',
#  'greenwood',
#  'yinchuan',
#  'akdepe',
#  'bilibino',
#  'rabo de peixe',
#  'georgetown',
#  'hithadhoo',
#  'paita',
#  'vila velha',
#  'yuryevets',
#  'umzimvubu',
#  'matelandia',
#  'palmer',
#  'petropavlovsk-kamchatskiy',
#  'lucapa',
#  'atlantic city',
#  'bonfim',
#  'norman wells',
#  'coquimbo',
#  'karratha',
#  'arman',
#  'ramgarh',
#  'khuzdar',
#  'terenga',
#  'mys shmidta',
#  'antofagasta',
#  'lompoc',
#  'dicabisagan',
#  'souillac',
#  'husavik',
#  'thinadhoo',
#  'lebu',
#  'klyuchi',
#  'kuche',
#  'dalinghe',
#  'terra santa',
#  'kabo',
#  'casablanca',
#  'gangotri',
#  'udachnyy',
#  'faya',
#  'jinka',
#  'boyolangu',
#  'yialos',
#  'bambous virieux',
#  'bam',
#  'barcelos',
#  'khatanga',
#  'gat',
#  'grand forks',
#  'puerto baquerizo moreno',
#  'harboore',
#  'eureka',
#  'shubarkuduk',
#  'bredasdorp',
#  'belushya guba',
#  'marsh harbour',
#  'klaksvik',
#  'yoichi',
#  'lagos',
#  'ribeira grande',
#  'manokwari',
#  'maturin',
#  'lagoa',
#  'laguna',
#  'ahipara',
#  'orotukan',
#  'kamenskoye',
#  'basco',
#  'yerbogachen',
#  'tsaratanana',
#  'mayo',
#  'manjacaze',
#  'waw',
#  'komsomolskiy',
#  'padre bernardo',
#  'mikasa',
#  'taltal',
#  'colmenar viejo',
#  'ziyang',
#  'hamilton',
#  'shirokiy',
#  'bone',
#  'saint george',
#  'tiksi',
#  'roebourne',
#  'victoria',
#  'skjervoy',
#  'ugoofaaru',
#  'kaifeng',
#  'sao gabriel da cachoeira',
#  'vaitupu',
#  'hay river',
#  'sao miguel do araguaia',
#  'tabiauea',
#  'yulara',
#  'cidreira',
#  'kristiinankaupunki',
#  'ati',
#  'san andres',
#  'camacha',
#  'sindor',
#  'labuhan',
#  'vagur',
#  'sur',
#  'taoudenni',
#  'tukrah',
#  'guerrero',
#  'lovozero',
#  'new norfolk',
#  'garm',
#  'simbahan',
#  'melilla',
#  'kavieng',
#  'vestmannaeyjar',
#  'karaton',
#  'teguise',
#  'khandbari',
#  'da nang',
#  'ngunguru',
#  'doctor pedro p. pena',
#  'los llanos de aridane',
#  'ormara',
#  'waipawa',
#  'te anau',
#  'grindavik',
#  'japura',
#  'sorland',
#  'nurobod',
#  'henties bay',
#  'luganville',
#  'santa cruz cabralia',
#  'acapulco',
#  'sabang',
#  'ballina',
#  'bardoli',
#  'ossora',
#  'sao joao da barra',
#  'esperance',
#  'san patricio',
#  'veraval',
#  'buri',
#  'khalkhal',
#  'agadez',
#  'touros',
#  'verkhoyansk',
#  'daoukro',
#  'sanmenxia',
#  'geraldton',
#  'boffa',
#  'spring valley',
#  'dingle',
#  'tumannyy',
#  'lolua',
#  'mergui',
#  'benito juarez',
#  'xuddur',
#  'volksrust',
#  'fortuna',
#  'sayyan',
#  'cap malheureux',
#  'la primavera',
#  'nchelenge',
#  'havoysund',
#  'port elizabeth',
#  'nyakahanga',
#  'bowen',
#  'katherine',
#  'beruwala',
#  'zhezkazgan',
#  'lasa',
#  'myitkyina',
#  'calbuco',
#  'saint-augustin',
#  'churapcha',
#  'lorengau',
#  'meyungs',
#  'tabou',
#  'mpongwe',
#  'obo',
#  'ribeira do pombal',
#  'ust-maya',
#  'tilichiki',
#  'cascais',
#  'tahara',
#  'monte carmelo',
#  'talcahuano',
#  'andra',
#  'nabire',
#  'chicama',
#  'lobez',
#  'bandarbeyla',
#  'katsuura',
#  'huilong',
#  'torbay',
#  'sola',
#  'iqaluit',
#  'port hardy',
#  'kununurra',
#  'sitka',
#  'kralendijk',
#  'sajkas',
#  'launceston',
#  'tuusula',
#  'zhigansk',
#  'khani',
#  'maningrida',
#  'nova olimpia',
#  'marcona',
#  'abnub',
#  'sibolga',
#  'kloulklubed',
#  'hohhot',
#  'thaba-tseka',
#  'mitrofanovka',
#  'kiama',
#  'sorong',
#  'laiya',
#  'arlit',
#  'nieves',
#  'kharan',
#  'margate',
#  'pindwara',
#  'shingu',
#  'davila',
#  'takahashi',
#  'jacareacanga',
#  'laredo',
#  'tual',
#  'alice springs',
#  'seoul',
#  'malpur',
#  'yanan',
#  'dien bien',
#  'maltahohe',
#  'nuevo imperial',
#  'lebowakgomo',
#  'paramonga',
#  'dovers',
#  'constitucion',
#  'doha',
#  'college',
#  'araouane',
#  'sawtell',
#  'denpasar',
#  'egvekinot',
#  'lujan',
#  'isangel',
#  'englehart',
#  'rungata',
#  'handan',
#  'agen',
#  'nelson bay',
#  'sobradinho',
#  'methoni',
#  'coremas',
#  'porto nacional',
#  'buzdyak',
#  'montague',
#  'sambava',
#  'jalu',
#  'gulmarg',
#  'honggang',
#  'puerto carreno',
#  'la ronge',
#  'victoria point',
#  'kodinsk',
#  'saint-pierre',
#  'vaxjo',
#  'maldonado',
#  'asau',
#  'makaryev',
#  'geelong',
#  'batagay',
#  'santo antonio do ica',
#  'knysna',
#  'rockport',
#  'nisia floresta',
#  'okhotsk',
#  'maceio',
#  'guerrero negro',
#  'kandi',
#  'mnogovershinnyy',
#  'half moon bay',
#  'vestmanna',
#  'bitung',
#  'alamogordo',
#  'nguiu',
#  'vavatenina',
#  'talnakh',
#  'uruzgan',
#  'guilin',
#  'port blair',
#  'yerofey pavlovich',
#  'ishigaki',
#  'adrar',
#  'auki',
#  'owase',
#  'honiara',
#  'praia da vitoria',
#  'caracoli',
#  'inhambane',
#  'oktyabrskiy',
#  'burnie',
#  'chengam',
#  'santa vitoria',
#  'borama',
#  'do rud',
#  'bhag',
#  'pangody',
#  'tromso',
#  'pangnirtung',
#  'pakokku',
#  'lazaro cardenas',
#  'oxford',
#  'mecca',
#  'vao',
#  'sandpoint',
#  'takab',
#  'hambantota',
#  'hun',
#  'xucheng',
#  'sundsvall',
#  'quatre cocos',
#  'berdyuzhye',
#  'mitchell',
#  'saleaula',
#  'kieta',
#  'asfi',
#  'great sankey',
#  'vostok',
#  'maniitsoq',
#  'nogales',
#  'orange',
#  'shizuishan',
#  'tianpeng',
#  'andenes',
#  'luanda',
#  'mitsamiouli',
#  'shimoda',
#  'progreso',
#  'ashtian',
#  'vila',
#  'bermejo',
#  'florida',
#  'pudem',
#  'saint-joseph',
#  'ilebo',
#  'adelaide',
#  'buzovna',
#  'sebinkarahisar',
#  'jiazi',
#  'broome',
#  'sao felix do xingu',
#  'sfantu gheorghe',
#  'puerto escondido',
#  'abu kamal',
#  'comodoro rivadavia',
#  'maragogi',
#  'alofi',
#  'saldanha',
#  'flinders',
#  'huarmey',
#  'hovd',
#  'san jose',
#  'punta',
#  'ulaangom',
#  'oranjemund',
#  'sao pedro',
#  'makakilo city',
#  'rodoc',
#  'tulle',
#  'kupang',
#  'pirovskoye',
#  'le port',
#  'thano bula khan',
#  'yining',
#  'goundam',
#  'coihaique',
#  'lidkoping',
#  'benin',
#  'yenagoa',
#  'langsa',
#  'key largo',
#  'severobaykalsk',
#  'butler',
#  'alotau',
#  'cartagena',
#  'vedaranniyam',
#  'bobovdol',
#  'antsohihy',
#  'ipixuna',
#  'santarem',
#  'mwinilunga',
#  'saint-leu',
#  'eyemouth',
#  'katobu',
#  'vanavara',
#  'tautira',
#  'zmeinogorsk',
#  'dauriya',
#  'pitimbu',
#  'port-cartier',
#  'mathathane',
#  'dharchula',
#  'iracoubo',
#  'harlingen',
#  'bardsir',
#  'ryotsu',
#  'anchorage',
#  'chivolo',
#  'kavaratti',
#  'whitehorse',
#  'salinopolis',
#  'spirit river',
#  'amparafaravola',
#  'leshukonskoye',
#  'khobi',
#  'tortoli',
#  'novoagansk',
#  'santa cruz',
#  'port moresby',
#  'oistins',
#  'tucumcari',
#  'becsehely',
#  'san rafael del sur',
#  'kailua',
#  'komatsu',
#  'kilindoni',
#  'moshenskoye',
#  'luderitz',
#  'renqiu',
#  'moose factory',
#  'ponot',
#  'vangaindrano',
#  'tacuarembo',
#  'christchurch',
#  'dalvik',
#  'plesetsk',
#  'kasongo-lunda',
#  'russell',
#  'namtsy',
#  'mamurras',
#  'malwan',
#  'san carlos de bariloche',
#  'capela',
#  'tocopilla',
#  'praya',
#  'carrickfergus',
#  'yirol',
#  'antigonish',
#  'cockburn town',
#  'gagatli',
#  'belmonte',
#  'nakusp',
#  'azimur',
#  'karamken',
#  'virginia beach',
#  'cosala',
#  'ilo',
#  'vardo',
#  'pompeia',
#  'altay',
#  'tala',
#  'northam',
#  'kovdor',
#  'biltine',
#  'kulhudhuffushi',
#  'the valley',
#  'aleksandrovskoye',
#  'songadh',
#  'sompeta',
#  'sao jose da coroa grande',
#  'correntina',
#  'mackenzie',
#  'colquechaca',
#  'grand gaube',
#  'saryshagan',
#  'acarau',
#  'palauig',
#  'kahului',
#  'cayenne',
#  'igarka',
#  'atambua',
#  'khasan',
#  'zeya',
#  'constantine',
#  'marystown',
#  'macau',
#  'sorvag',
#  'aranos',
#  'abu dhabi',
#  'khorinsk',
#  'falealupo',
#  'nizhnyaya omka',
#  'werda',
#  'birao',
#  'boma',
#  'novikovo',
#  'novomichurinsk',
#  'berezovka',
#  'winnemucca',
#  'ketchikan',
#  'wajima',
#  'effingham',
#  'curup',
#  'samusu',
#  'yuanping',
#  'channel-port aux basques',
#  'liepaja',
#  'bonthe',
#  'samarinda',
#  'hofn',
#  'antequera',
#  'palabuhanratu',
#  'acevedo',
#  'nouakchott',
#  'mount isa',
#  'mtwara',
#  'teya',
#  'natitingou',
#  'panama city',
#  'lashio',
#  'haibowan',
#  'gremyachye',
#  'buqayq',
#  'colon',
#  'jabiru',
#  'salvador',
#  'coulihaut',
#  'saint anthony',
#  'dzhebariki-khaya',
#  'derac',
#  'namibe',
#  'talesh',
#  'gainesville',
#  'ventspils',
#  'luang prabang',
#  'cape coast',
#  'terrace',
#  'yanam',
#  'gornopravdinsk',
#  'gravdal',
#  'baft',
#  'valparaiso',
#  'palmares do sul',
#  'rolim de moura',
#  'tsabong',
#  'tarata',
#  'boa vista',
#  'sakakah',
#  'mrirt',
#  'kharp',
#  'longhua',
#  'tailai',
#  'tocache',
#  'semey',
#  'chuzhou',
#  'atoyac',
#  'kamenka',
#  'coos bay',
#  'amazar',
#  'north bend',
#  'avera',
#  'sao filipe',
#  'narsaq',
#  'shelburne',
#  'nova olinda do norte',
#  'othonoi',
#  'havre-saint-pierre',
#  'kushima',
#  'yurla',
#  'znamenskoye',
#  'mercedes']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Weather description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | porto novo
# Processing Record 4 of Set 1 | bilma
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | necochea
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | kenai
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | rebrikha
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | fort nelson
# Processing Record 20 of Set 1 | portland
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | bubaque
# Processing Record 25 of Set 1 | aykhal
# Processing Record 26 of Set 1 | teguldet
# Processing Record 27 of Set 1 | omsukchan
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | clemson
# Processing Record 31 of Set 1 | shahganj
# Processing Record 32 of Set 1 | wanning
# Processing Record 33 of Set 1 | revyakino
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | riyadh
# Processing Record 39 of Set 1 | ambon
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | corinto
# Processing Record 42 of Set 1 | tirumala
# Processing Record 43 of Set 1 | seljord
# Processing Record 44 of Set 1 | marawi
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | umm kaddadah
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | ponta delgada
# Processing Record 1 of Set 2 | haines junction
# Processing Record 2 of Set 2 | solnechnyy
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | ayodhya
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | manta
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | okha
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | port hawkesbury
# Processing Record 11 of Set 2 | evinayong
# Processing Record 12 of Set 2 | meulaboh
# Processing Record 13 of Set 2 | tete
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | plettenberg bay
# Processing Record 16 of Set 2 | codrington
# Processing Record 17 of Set 2 | dunedin
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | bozeman
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | port lincoln
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | iquique
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | kollam
# Processing Record 30 of Set 2 | biak
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | uige
# Processing Record 34 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | le creusot
# Processing Record 37 of Set 2 | kushmurun
# Processing Record 38 of Set 2 | billings
# Processing Record 39 of Set 2 | atikokan
# Processing Record 40 of Set 2 | hokitika
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | aklavik
# Processing Record 43 of Set 2 | bo
# City not found. Skipping...
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | gornozavodsk
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | karmana
# City not found. Skipping...
# Processing Record 48 of Set 2 | chernyanka
# Processing Record 49 of Set 2 | visnes
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | bitkine
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | balakliya
# Processing Record 5 of Set 3 | cody
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | sena madureira
# Processing Record 8 of Set 3 | garden city
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | praia
# Processing Record 11 of Set 3 | petatlan
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | archidona
# Processing Record 14 of Set 3 | olga
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | sept-iles
# Processing Record 17 of Set 3 | marsaxlokk
# Processing Record 18 of Set 3 | eyl
# Processing Record 19 of Set 3 | bonavista
# Processing Record 20 of Set 3 | tuy hoa
# Processing Record 21 of Set 3 | buala
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | mandera
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | dhidhdhoo
# Processing Record 27 of Set 3 | waingapu
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | webuye
# Processing Record 30 of Set 3 | rio gallegos
# Processing Record 31 of Set 3 | kalmeshwar
# Processing Record 32 of Set 3 | lucea
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | prainha
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | nyurba
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | sorocaba
# Processing Record 40 of Set 3 | bembereke
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | padang
# Processing Record 44 of Set 3 | pacific grove
# Processing Record 45 of Set 3 | anloga
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | am timan
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | koumac
# Processing Record 50 of Set 3 | coahuayana
# Processing Record 1 of Set 4 | samarai
# Processing Record 2 of Set 4 | columbus
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | vanimo
# Processing Record 8 of Set 4 | chernushka
# Processing Record 9 of Set 4 | tazovskiy
# Processing Record 10 of Set 4 | alyangula
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | oskemen
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | taonan
# Processing Record 15 of Set 4 | lodwar
# Processing Record 16 of Set 4 | zaozerne
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | nome
# Processing Record 19 of Set 4 | burica
# City not found. Skipping...
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | izacic
# Processing Record 22 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 4 | namatanai
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | natchez
# Processing Record 26 of Set 4 | greenwood
# Processing Record 27 of Set 4 | yinchuan
# Processing Record 28 of Set 4 | akdepe
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | rabo de peixe
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | hithadhoo
# Processing Record 33 of Set 4 | paita
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | yuryevets
# Processing Record 36 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 4 | matelandia
# Processing Record 38 of Set 4 | palmer
# Processing Record 39 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 4 | lucapa
# Processing Record 41 of Set 4 | atlantic city
# Processing Record 42 of Set 4 | bonfim
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | karratha
# Processing Record 46 of Set 4 | arman
# Processing Record 47 of Set 4 | ramgarh
# Processing Record 48 of Set 4 | khuzdar
# Processing Record 49 of Set 4 | terenga
# City not found. Skipping...
# Processing Record 50 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 5 | antofagasta
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | dicabisagan
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | thinadhoo
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | klyuchi
# Processing Record 9 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 5 | dalinghe
# City not found. Skipping...
# Processing Record 11 of Set 5 | terra santa
# Processing Record 12 of Set 5 | kabo
# Processing Record 13 of Set 5 | casablanca
# Processing Record 14 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 15 of Set 5 | udachnyy
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | jinka
# Processing Record 18 of Set 5 | boyolangu
# Processing Record 19 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | bam
# Processing Record 22 of Set 5 | barcelos
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | gat
# Processing Record 25 of Set 5 | grand forks
# Processing Record 26 of Set 5 | puerto baquerizo moreno
# Processing Record 27 of Set 5 | harboore
# Processing Record 28 of Set 5 | eureka
# Processing Record 29 of Set 5 | shubarkuduk
# Processing Record 30 of Set 5 | bredasdorp
# Processing Record 31 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 5 | marsh harbour
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | yoichi
# Processing Record 35 of Set 5 | lagos
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | manokwari
# Processing Record 38 of Set 5 | maturin
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | laguna
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | orotukan
# Processing Record 43 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 5 | basco
# Processing Record 45 of Set 5 | yerbogachen
# Processing Record 46 of Set 5 | tsaratanana
# Processing Record 47 of Set 5 | mayo
# Processing Record 48 of Set 5 | manjacaze
# Processing Record 49 of Set 5 | waw
# Processing Record 50 of Set 5 | komsomolskiy
# Processing Record 1 of Set 6 | padre bernardo
# Processing Record 2 of Set 6 | mikasa
# Processing Record 3 of Set 6 | taltal
# Processing Record 4 of Set 6 | colmenar viejo
# Processing Record 5 of Set 6 | ziyang
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | shirokiy
# Processing Record 8 of Set 6 | bone
# Processing Record 9 of Set 6 | saint george
# Processing Record 10 of Set 6 | tiksi
# Processing Record 11 of Set 6 | roebourne
# Processing Record 12 of Set 6 | victoria
# Processing Record 13 of Set 6 | skjervoy
# Processing Record 14 of Set 6 | ugoofaaru
# Processing Record 15 of Set 6 | kaifeng
# Processing Record 16 of Set 6 | sao gabriel da cachoeira
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | hay river
# Processing Record 19 of Set 6 | sao miguel do araguaia
# Processing Record 20 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | kristiinankaupunki
# Processing Record 24 of Set 6 | ati
# Processing Record 25 of Set 6 | san andres
# Processing Record 26 of Set 6 | camacha
# Processing Record 27 of Set 6 | sindor
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | vagur
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | taoudenni
# Processing Record 32 of Set 6 | tukrah
# Processing Record 33 of Set 6 | guerrero
# Processing Record 34 of Set 6 | lovozero
# Processing Record 35 of Set 6 | new norfolk
# Processing Record 36 of Set 6 | garm
# City not found. Skipping...
# Processing Record 37 of Set 6 | simbahan
# Processing Record 38 of Set 6 | melilla
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | karaton
# Processing Record 42 of Set 6 | teguise
# Processing Record 43 of Set 6 | khandbari
# Processing Record 44 of Set 6 | da nang
# Processing Record 45 of Set 6 | ngunguru
# Processing Record 46 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 6 | los llanos de aridane
# Processing Record 48 of Set 6 | ormara
# Processing Record 49 of Set 6 | waipawa
# Processing Record 50 of Set 6 | te anau
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | japura
# Processing Record 3 of Set 7 | sorland
# Processing Record 4 of Set 7 | nurobod
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | luganville
# Processing Record 7 of Set 7 | santa cruz cabralia
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | sabang
# Processing Record 10 of Set 7 | ballina
# Processing Record 11 of Set 7 | bardoli
# Processing Record 12 of Set 7 | ossora
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | veraval
# Processing Record 17 of Set 7 | buri
# Processing Record 18 of Set 7 | khalkhal
# Processing Record 19 of Set 7 | agadez
# Processing Record 20 of Set 7 | touros
# Processing Record 21 of Set 7 | verkhoyansk
# Processing Record 22 of Set 7 | daoukro
# Processing Record 23 of Set 7 | sanmenxia
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | boffa
# Processing Record 26 of Set 7 | spring valley
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 7 | benito juarez
# Processing Record 32 of Set 7 | xuddur
# Processing Record 33 of Set 7 | volksrust
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | sayyan
# Processing Record 36 of Set 7 | cap malheureux
# Processing Record 37 of Set 7 | la primavera
# Processing Record 38 of Set 7 | nchelenge
# Processing Record 39 of Set 7 | havoysund
# Processing Record 40 of Set 7 | port elizabeth
# Processing Record 41 of Set 7 | nyakahanga
# Processing Record 42 of Set 7 | bowen
# Processing Record 43 of Set 7 | katherine
# Processing Record 44 of Set 7 | beruwala
# Processing Record 45 of Set 7 | zhezkazgan
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | myitkyina
# Processing Record 48 of Set 7 | calbuco
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | churapcha
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 8 | tabou
# Processing Record 4 of Set 8 | mpongwe
# Processing Record 5 of Set 8 | obo
# Processing Record 6 of Set 8 | ribeira do pombal
# Processing Record 7 of Set 8 | ust-maya
# Processing Record 8 of Set 8 | tilichiki
# Processing Record 9 of Set 8 | cascais
# Processing Record 10 of Set 8 | tahara
# Processing Record 11 of Set 8 | monte carmelo
# Processing Record 12 of Set 8 | talcahuano
# Processing Record 13 of Set 8 | andra
# Processing Record 14 of Set 8 | nabire
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | lobez
# Processing Record 17 of Set 8 | bandarbeyla
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | huilong
# Processing Record 20 of Set 8 | torbay
# Processing Record 21 of Set 8 | sola
# Processing Record 22 of Set 8 | iqaluit
# Processing Record 23 of Set 8 | port hardy
# Processing Record 24 of Set 8 | kununurra
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | kralendijk
# Processing Record 27 of Set 8 | sajkas
# Processing Record 28 of Set 8 | launceston
# Processing Record 29 of Set 8 | tuusula
# Processing Record 30 of Set 8 | zhigansk
# Processing Record 31 of Set 8 | khani
# Processing Record 32 of Set 8 | maningrida
# Processing Record 33 of Set 8 | nova olimpia
# Processing Record 34 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | abnub
# Processing Record 36 of Set 8 | sibolga
# Processing Record 37 of Set 8 | kloulklubed
# Processing Record 38 of Set 8 | hohhot
# Processing Record 39 of Set 8 | thaba-tseka
# Processing Record 40 of Set 8 | mitrofanovka
# Processing Record 41 of Set 8 | kiama
# Processing Record 42 of Set 8 | sorong
# Processing Record 43 of Set 8 | laiya
# Processing Record 44 of Set 8 | arlit
# Processing Record 45 of Set 8 | nieves
# Processing Record 46 of Set 8 | kharan
# Processing Record 47 of Set 8 | margate
# Processing Record 48 of Set 8 | pindwara
# Processing Record 49 of Set 8 | shingu
# Processing Record 50 of Set 8 | davila
# Processing Record 1 of Set 9 | takahashi
# Processing Record 2 of Set 9 | jacareacanga
# Processing Record 3 of Set 9 | laredo
# Processing Record 4 of Set 9 | tual
# Processing Record 5 of Set 9 | alice springs
# Processing Record 6 of Set 9 | seoul
# Processing Record 7 of Set 9 | malpur
# Processing Record 8 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 10 of Set 9 | maltahohe
# Processing Record 11 of Set 9 | nuevo imperial
# Processing Record 12 of Set 9 | lebowakgomo
# Processing Record 13 of Set 9 | paramonga
# Processing Record 14 of Set 9 | dovers
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | doha
# Processing Record 17 of Set 9 | college
# Processing Record 18 of Set 9 | araouane
# Processing Record 19 of Set 9 | sawtell
# Processing Record 20 of Set 9 | denpasar
# Processing Record 21 of Set 9 | egvekinot
# Processing Record 22 of Set 9 | lujan
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | englehart
# Processing Record 25 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 9 | handan
# Processing Record 27 of Set 9 | agen
# Processing Record 28 of Set 9 | nelson bay
# Processing Record 29 of Set 9 | sobradinho
# Processing Record 30 of Set 9 | methoni
# Processing Record 31 of Set 9 | coremas
# Processing Record 32 of Set 9 | porto nacional
# Processing Record 33 of Set 9 | buzdyak
# Processing Record 34 of Set 9 | montague
# Processing Record 35 of Set 9 | sambava
# Processing Record 36 of Set 9 | jalu
# Processing Record 37 of Set 9 | gulmarg
# Processing Record 38 of Set 9 | honggang
# Processing Record 39 of Set 9 | puerto carreno
# Processing Record 40 of Set 9 | la ronge
# Processing Record 41 of Set 9 | victoria point
# Processing Record 42 of Set 9 | kodinsk
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | vaxjo
# Processing Record 45 of Set 9 | maldonado
# Processing Record 46 of Set 9 | asau
# Processing Record 47 of Set 9 | makaryev
# Processing Record 48 of Set 9 | geelong
# Processing Record 49 of Set 9 | batagay
# Processing Record 50 of Set 9 | santo antonio do ica
# Processing Record 1 of Set 10 | knysna
# Processing Record 2 of Set 10 | rockport
# Processing Record 3 of Set 10 | nisia floresta
# Processing Record 4 of Set 10 | okhotsk
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | guerrero negro
# Processing Record 7 of Set 10 | kandi
# Processing Record 8 of Set 10 | mnogovershinnyy
# Processing Record 9 of Set 10 | half moon bay
# Processing Record 10 of Set 10 | vestmanna
# Processing Record 11 of Set 10 | bitung
# Processing Record 12 of Set 10 | alamogordo
# Processing Record 13 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 10 | vavatenina
# Processing Record 15 of Set 10 | talnakh
# Processing Record 16 of Set 10 | uruzgan
# Processing Record 17 of Set 10 | guilin
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | yerofey pavlovich
# Processing Record 20 of Set 10 | ishigaki
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | auki
# Processing Record 23 of Set 10 | owase
# Processing Record 24 of Set 10 | honiara
# Processing Record 25 of Set 10 | praia da vitoria
# Processing Record 26 of Set 10 | caracoli
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | oktyabrskiy
# Processing Record 29 of Set 10 | burnie
# Processing Record 30 of Set 10 | chengam
# Processing Record 31 of Set 10 | santa vitoria
# Processing Record 32 of Set 10 | borama
# City not found. Skipping...
# Processing Record 33 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 34 of Set 10 | bhag
# Processing Record 35 of Set 10 | pangody
# Processing Record 36 of Set 10 | tromso
# Processing Record 37 of Set 10 | pangnirtung
# Processing Record 38 of Set 10 | pakokku
# Processing Record 39 of Set 10 | lazaro cardenas
# Processing Record 40 of Set 10 | oxford
# Processing Record 41 of Set 10 | mecca
# Processing Record 42 of Set 10 | vao
# Processing Record 43 of Set 10 | sandpoint
# Processing Record 44 of Set 10 | takab
# Processing Record 45 of Set 10 | hambantota
# Processing Record 46 of Set 10 | hun
# Processing Record 47 of Set 10 | xucheng
# Processing Record 48 of Set 10 | sundsvall
# Processing Record 49 of Set 10 | quatre cocos
# Processing Record 50 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 1 of Set 11 | mitchell
# Processing Record 2 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 11 | kieta
# Processing Record 4 of Set 11 | asfi
# Processing Record 5 of Set 11 | great sankey
# Processing Record 6 of Set 11 | vostok
# Processing Record 7 of Set 11 | maniitsoq
# Processing Record 8 of Set 11 | nogales
# Processing Record 9 of Set 11 | orange
# Processing Record 10 of Set 11 | shizuishan
# Processing Record 11 of Set 11 | tianpeng
# Processing Record 12 of Set 11 | andenes
# Processing Record 13 of Set 11 | luanda
# Processing Record 14 of Set 11 | mitsamiouli
# Processing Record 15 of Set 11 | shimoda
# Processing Record 16 of Set 11 | progreso
# Processing Record 17 of Set 11 | ashtian
# Processing Record 18 of Set 11 | vila
# Processing Record 19 of Set 11 | bermejo
# Processing Record 20 of Set 11 | florida
# Processing Record 21 of Set 11 | pudem
# Processing Record 22 of Set 11 | saint-joseph
# Processing Record 23 of Set 11 | ilebo
# Processing Record 24 of Set 11 | adelaide
# Processing Record 25 of Set 11 | buzovna
# Processing Record 26 of Set 11 | sebinkarahisar
# Processing Record 27 of Set 11 | jiazi
# Processing Record 28 of Set 11 | broome
# Processing Record 29 of Set 11 | sao felix do xingu
# Processing Record 30 of Set 11 | sfantu gheorghe
# Processing Record 31 of Set 11 | puerto escondido
# Processing Record 32 of Set 11 | abu kamal
# Processing Record 33 of Set 11 | comodoro rivadavia
# Processing Record 34 of Set 11 | maragogi
# Processing Record 35 of Set 11 | alofi
# Processing Record 36 of Set 11 | saldanha
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | huarmey
# Processing Record 39 of Set 11 | hovd
# Processing Record 40 of Set 11 | san jose
# Processing Record 41 of Set 11 | punta
# Processing Record 42 of Set 11 | ulaangom
# Processing Record 43 of Set 11 | oranjemund
# Processing Record 44 of Set 11 | sao pedro
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | rodoc
# Processing Record 47 of Set 11 | tulle
# Processing Record 48 of Set 11 | kupang
# Processing Record 49 of Set 11 | pirovskoye
# Processing Record 50 of Set 11 | le port
# Processing Record 1 of Set 12 | thano bula khan
# City not found. Skipping...
# Processing Record 2 of Set 12 | yining
# Processing Record 3 of Set 12 | goundam
# Processing Record 4 of Set 12 | coihaique
# Processing Record 5 of Set 12 | lidkoping
# Processing Record 6 of Set 12 | benin
# Processing Record 7 of Set 12 | yenagoa
# Processing Record 8 of Set 12 | langsa
# Processing Record 9 of Set 12 | key largo
# Processing Record 10 of Set 12 | severobaykalsk
# Processing Record 11 of Set 12 | butler
# Processing Record 12 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 12 | cartagena
# Processing Record 14 of Set 12 | vedaranniyam
# City not found. Skipping...
# Processing Record 15 of Set 12 | bobovdol
# Processing Record 16 of Set 12 | antsohihy
# Processing Record 17 of Set 12 | ipixuna
# Processing Record 18 of Set 12 | santarem
# Processing Record 19 of Set 12 | mwinilunga
# Processing Record 20 of Set 12 | saint-leu
# Processing Record 21 of Set 12 | eyemouth
# Processing Record 22 of Set 12 | katobu
# Processing Record 23 of Set 12 | vanavara
# Processing Record 24 of Set 12 | tautira
# Processing Record 25 of Set 12 | zmeinogorsk
# Processing Record 26 of Set 12 | dauriya
# Processing Record 27 of Set 12 | pitimbu
# Processing Record 28 of Set 12 | port-cartier
# Processing Record 29 of Set 12 | mathathane
# Processing Record 30 of Set 12 | dharchula
# Processing Record 31 of Set 12 | iracoubo
# Processing Record 32 of Set 12 | harlingen
# Processing Record 33 of Set 12 | bardsir
# Processing Record 34 of Set 12 | ryotsu
# Processing Record 35 of Set 12 | anchorage
# Processing Record 36 of Set 12 | chivolo
# Processing Record 37 of Set 12 | kavaratti
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | salinopolis
# Processing Record 40 of Set 12 | spirit river
# Processing Record 41 of Set 12 | amparafaravola
# Processing Record 42 of Set 12 | leshukonskoye
# Processing Record 43 of Set 12 | khobi
# Processing Record 44 of Set 12 | tortoli
# Processing Record 45 of Set 12 | novoagansk
# Processing Record 46 of Set 12 | santa cruz
# Processing Record 47 of Set 12 | port moresby
# Processing Record 48 of Set 12 | oistins
# Processing Record 49 of Set 12 | tucumcari
# Processing Record 50 of Set 12 | becsehely
# Processing Record 1 of Set 13 | san rafael del sur
# Processing Record 2 of Set 13 | kailua
# Processing Record 3 of Set 13 | komatsu
# Processing Record 4 of Set 13 | kilindoni
# Processing Record 5 of Set 13 | moshenskoye
# Processing Record 6 of Set 13 | luderitz
# Processing Record 7 of Set 13 | renqiu
# Processing Record 8 of Set 13 | moose factory
# Processing Record 9 of Set 13 | ponot
# Processing Record 10 of Set 13 | vangaindrano
# Processing Record 11 of Set 13 | tacuarembo
# Processing Record 12 of Set 13 | christchurch
# Processing Record 13 of Set 13 | dalvik
# Processing Record 14 of Set 13 | plesetsk
# Processing Record 15 of Set 13 | kasongo-lunda
# Processing Record 16 of Set 13 | russell
# Processing Record 17 of Set 13 | namtsy
# Processing Record 18 of Set 13 | mamurras
# Processing Record 19 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 13 | san carlos de bariloche
# Processing Record 21 of Set 13 | capela
# Processing Record 22 of Set 13 | tocopilla
# Processing Record 23 of Set 13 | praya
# Processing Record 24 of Set 13 | carrickfergus
# Processing Record 25 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 13 | antigonish
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | gagatli
# Processing Record 29 of Set 13 | belmonte
# Processing Record 30 of Set 13 | nakusp
# Processing Record 31 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 13 | karamken
# City not found. Skipping...
# Processing Record 33 of Set 13 | virginia beach
# Processing Record 34 of Set 13 | cosala
# Processing Record 35 of Set 13 | ilo
# Processing Record 36 of Set 13 | vardo
# Processing Record 37 of Set 13 | pompeia
# Processing Record 38 of Set 13 | altay
# Processing Record 39 of Set 13 | tala
# Processing Record 40 of Set 13 | northam
# Processing Record 41 of Set 13 | kovdor
# Processing Record 42 of Set 13 | biltine
# Processing Record 43 of Set 13 | kulhudhuffushi
# Processing Record 44 of Set 13 | the valley
# Processing Record 45 of Set 13 | aleksandrovskoye
# Processing Record 46 of Set 13 | songadh
# Processing Record 47 of Set 13 | sompeta
# Processing Record 48 of Set 13 | sao jose da coroa grande
# Processing Record 49 of Set 13 | correntina
# Processing Record 50 of Set 13 | mackenzie
# Processing Record 1 of Set 14 | colquechaca
# Processing Record 2 of Set 14 | grand gaube
# Processing Record 3 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 14 | acarau
# Processing Record 5 of Set 14 | palauig
# Processing Record 6 of Set 14 | kahului
# Processing Record 7 of Set 14 | cayenne
# Processing Record 8 of Set 14 | igarka
# Processing Record 9 of Set 14 | atambua
# Processing Record 10 of Set 14 | khasan
# Processing Record 11 of Set 14 | zeya
# Processing Record 12 of Set 14 | constantine
# Processing Record 13 of Set 14 | marystown
# Processing Record 14 of Set 14 | macau
# Processing Record 15 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 14 | aranos
# Processing Record 17 of Set 14 | abu dhabi
# Processing Record 18 of Set 14 | khorinsk
# Processing Record 19 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 14 | nizhnyaya omka
# Processing Record 21 of Set 14 | werda
# Processing Record 22 of Set 14 | birao
# Processing Record 23 of Set 14 | boma
# Processing Record 24 of Set 14 | novikovo
# Processing Record 25 of Set 14 | novomichurinsk
# Processing Record 26 of Set 14 | berezovka
# Processing Record 27 of Set 14 | winnemucca
# Processing Record 28 of Set 14 | ketchikan
# Processing Record 29 of Set 14 | wajima
# Processing Record 30 of Set 14 | effingham
# Processing Record 31 of Set 14 | curup
# Processing Record 32 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 14 | yuanping
# Processing Record 34 of Set 14 | channel-port aux basques
# Processing Record 35 of Set 14 | liepaja
# Processing Record 36 of Set 14 | bonthe
# Processing Record 37 of Set 14 | samarinda
# Processing Record 38 of Set 14 | hofn
# Processing Record 39 of Set 14 | antequera
# Processing Record 40 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 14 | acevedo
# Processing Record 42 of Set 14 | nouakchott
# Processing Record 43 of Set 14 | mount isa
# Processing Record 44 of Set 14 | mtwara
# Processing Record 45 of Set 14 | teya
# Processing Record 46 of Set 14 | natitingou
# Processing Record 47 of Set 14 | panama city
# Processing Record 48 of Set 14 | lashio
# Processing Record 49 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 14 | gremyachye
# City not found. Skipping...
# Processing Record 1 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 15 | colon
# Processing Record 3 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 4 of Set 15 | salvador
# Processing Record 5 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 6 of Set 15 | saint anthony
# Processing Record 7 of Set 15 | dzhebariki-khaya
# Processing Record 8 of Set 15 | derac
# Processing Record 9 of Set 15 | namibe
# Processing Record 10 of Set 15 | talesh
# City not found. Skipping...
# Processing Record 11 of Set 15 | gainesville
# Processing Record 12 of Set 15 | ventspils
# Processing Record 13 of Set 15 | luang prabang
# Processing Record 14 of Set 15 | cape coast
# Processing Record 15 of Set 15 | terrace
# Processing Record 16 of Set 15 | yanam
# Processing Record 17 of Set 15 | gornopravdinsk
# Processing Record 18 of Set 15 | gravdal
# Processing Record 19 of Set 15 | baft
# Processing Record 20 of Set 15 | valparaiso
# Processing Record 21 of Set 15 | palmares do sul
# Processing Record 22 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 15 | tsabong
# Processing Record 24 of Set 15 | tarata
# Processing Record 25 of Set 15 | boa vista
# Processing Record 26 of Set 15 | sakakah
# Processing Record 27 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 15 | kharp
# Processing Record 29 of Set 15 | longhua
# Processing Record 30 of Set 15 | tailai
# Processing Record 31 of Set 15 | tocache
# Processing Record 32 of Set 15 | semey
# Processing Record 33 of Set 15 | chuzhou
# Processing Record 34 of Set 15 | atoyac
# Processing Record 35 of Set 15 | kamenka
# Processing Record 36 of Set 15 | coos bay
# Processing Record 37 of Set 15 | amazar
# Processing Record 38 of Set 15 | north bend
# Processing Record 39 of Set 15 | avera
# Processing Record 40 of Set 15 | sao filipe
# Processing Record 41 of Set 15 | narsaq
# Processing Record 42 of Set 15 | shelburne
# Processing Record 43 of Set 15 | nova olinda do norte
# Processing Record 44 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 45 of Set 15 | havre-saint-pierre
# Processing Record 46 of Set 15 | kushima
# Processing Record 47 of Set 15 | yurla
# Processing Record 48 of Set 15 | znamenskoye
# Processing Record 49 of Set 15 | mercedes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia -54.8000  -68.3000     53.26        40          40
# 1    Butaritari   3.0707  172.7902     81.27        78          61
# 2    Porto Novo   6.4965    2.6036     84.02        78          96
# 3         Bilma  18.6853   12.9164     78.04        15         100
# 4    Nanortalik  60.1432  -45.2371     41.95        92         100
# 5      Necochea -38.5473  -58.7368     63.18        88         100
# 6  Puerto Ayora  -0.7393  -90.3518     76.96        80          96
# 7  Punta Arenas -53.1500  -70.9167     51.91        62          75
# 8          Hilo  19.7297 -155.0900     71.33        78           1
# 9   Tuktoyaktuk  69.4541 -133.0374     -7.60        71          90
#
#    Wind Speed Country                 Date Weather description
# 0       23.02      AR  2021-11-28 18:32:44    scattered clouds
# 1       13.31      KI  2021-11-28 18:32:44       broken clouds
# 2        7.99      BJ  2021-11-28 18:32:45     overcast clouds
# 3        7.47      NE  2021-11-28 18:32:45     overcast clouds
# 4       15.84      GL  2021-11-28 18:32:45          light rain
# 5        9.69      AR  2021-11-28 18:30:03          light rain
# 6        9.78      EC  2021-11-28 18:29:40     overcast clouds
# 7       29.93      CL  2021-11-28 18:32:46          light rain
# 8        4.61      US  2021-11-28 18:32:47           clear sky
# 9       18.41      CA  2021-11-28 18:32:47          light snow

# %%
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Weather description']
final_city_data_df=city_data_df[new_column_order]
final_city_data_df
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0               Ushuaia      AR  2021-11-28 18:32:44 -54.8000  -68.3000
# 1            Butaritari      KI  2021-11-28 18:32:44   3.0707  172.7902
# 2            Porto Novo      BJ  2021-11-28 18:32:45   6.4965    2.6036
# 3                 Bilma      NE  2021-11-28 18:32:45  18.6853   12.9164
# 4            Nanortalik      GL  2021-11-28 18:32:45  60.1432  -45.2371
# ..                  ...     ...                  ...      ...       ...
# 683  Havre-Saint-Pierre      CA  2021-11-28 18:50:43  50.2334  -63.5986
# 684             Kushima      JP  2021-11-28 18:50:43  31.4583  131.2333
# 685               Yurla      RU  2021-11-28 18:50:43  59.3259   54.3223
# 686         Znamenskoye      RU  2021-11-28 18:50:44  57.1281   73.8282
# 687            Mercedes      AR  2021-11-28 18:50:44 -34.6515  -59.4307
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Weather description
# 0       53.26        40          40       23.02    scattered clouds
# 1       81.27        78          61       13.31       broken clouds
# 2       84.02        78          96        7.99     overcast clouds
# 3       78.04        15         100        7.47     overcast clouds
# 4       41.95        92         100       15.84          light rain
# ..        ...       ...         ...         ...                 ...
# 683     35.60        80          90       12.66     overcast clouds
# 684     50.97        74          67        5.01       broken clouds
# 685     30.79        91         100       11.32     overcast clouds
# 686     13.82        94          95        5.70     overcast clouds
# 687     62.01        95         100        8.12       moderate rain
#
# [688 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
